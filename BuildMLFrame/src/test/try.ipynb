# %%
# !ls
# Out:
# a.py		    cancer_patient.xlsx  try.ipynb
# cancer_patient.csv  __init__.py		 WineQT.csv

# %%
# !python3 /home/aditta/Desktop/BuildMLModel/BuildMLFrame/src/main.py --path /home/aditta/Desktop/BuildMLModel/BuildMLFrame/src/test/cancer_patient.xlsx --label Level --encoder first
# Out:
# 2023-03-23 12:40:09,509 - INFO - Memory usage of properties dataframe is >> 0.19085693359375 MB
# 2023-03-23 12:40:09,510 - INFO - Change columns name
# 2023-03-23 12:40:09,512 - INFO - File Saved >> storage/name_chager.txt
# 2023-03-23 12:40:09,529 - INFO - No null values found
# 2023-03-23 12:40:09,529 - INFO - Label: Level type object >> Converting in neumerical
# 2023-03-23 12:40:09,534 - INFO - File Saved >> storage/first.joblib
#     Patient Id  Age  Gender  ...  Dry Cough  Snoring  Level
# 0           P1   33       1  ...          3        4      1
# 1          P10   17       1  ...          7        2      2
# 2         P100   35       1  ...          7        2      0
# 3        P1000   37       1  ...          7        5      0
# 4         P101   46       1  ...          2        3      0
# ..         ...  ...     ...  ...        ...      ...    ...
# 995       P995   44       1  ...          5        3      0
# 996       P996   37       2  ...          1        4      0
# ...

# %%
import pandas as pd
d = "/home/aditta/Desktop/BuildMLModel/BuildMLFrame/src/test/cancer_patient.xlsx"
df = pd.read_excel(d)
df
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
sorted(df.Level.unique())
# Out:
# ['High', 'Low', 'Medium']

# %%
df.Dry Cough.unique()
# Out:
#   Cell In[83], line 1
#     df.Dry Cough.unique()
#            ^
# SyntaxError: invalid syntax

# %%
l = len(df.columns.tolist())
m = df.columns.tolist()

# %%
new = []
for k in range(l):
    if len(df[m[k]].name.split()) > 1:
        name = df[m[k]].name.split()
        joint = "_".join(name).lower()
        new.append(joint)
new
# Out:
# ['patient_id',
#  'air_pollution',
#  'alcohol_use',
#  'dust_allergy',
#  'occupational_hazards',
#  'genetic_risk',
#  'chronic_lung_disease',
#  'balanced_diet',
#  'passive_smoker',
#  'chest_pain',
#  'coughing_of_blood',
#  'weight_loss',
#  'shortness_of_breath',
#  'swallowing_difficulty',
#  'clubbing_of_finger_nails',
#  'frequent_cold',
#  'dry_cough']

# %%
m
# Out:
# ['Patient Id',
#  'Age',
#  'Gender',
#  'Air Pollution',
#  'Alcohol use',
#  'Dust Allergy',
#  'OccuPational Hazards',
#  'Genetic Risk',
#  'chronic Lung Disease',
#  'Balanced Diet',
#  'Obesity',
#  'Smoking',
#  'Passive Smoker',
#  'Chest Pain',
#  'Coughing of Blood',
#  'Fatigue',
#  'Weight Loss',
#  'Shortness of Breath',
#  'Wheezing',
#  'Swallowing Difficulty',
#  'Clubbing of Finger Nails',
#  'Frequent Cold',
#  'Dry Cough',
#  'Snoring',
#  'Level']

# %%
dictionary = {k: v for k, v in zip(m, new)}
dictionary
# Out:
# {'Patient Id': 'patient_id',
#  'Age': 'air_pollution',
#  'Gender': 'alcohol_use',
#  'Air Pollution': 'dust_allergy',
#  'Alcohol use': 'occupational_hazards',
#  'Dust Allergy': 'genetic_risk',
#  'OccuPational Hazards': 'chronic_lung_disease',
#  'Genetic Risk': 'balanced_diet',
#  'chronic Lung Disease': 'passive_smoker',
#  'Balanced Diet': 'chest_pain',
#  'Obesity': 'coughing_of_blood',
#  'Smoking': 'weight_loss',
#  'Passive Smoker': 'shortness_of_breath',
#  'Chest Pain': 'swallowing_difficulty',
#  'Coughing of Blood': 'clubbing_of_finger_nails',
#  'Fatigue': 'frequent_cold',
#  'Weight Loss': 'dry_cough'}

# %%
df.rename(columns=dictionary, errors="raise")
# Out:
#     patient_id  air_pollution  alcohol_use  dust_allergy  \
# 0           P1             33            1             2
# 1          P10             17            1             3
# 2         P100             35            1             4
# 3        P1000             37            1             7
# 4         P101             46            1             6
# ..         ...            ...          ...           ...
# 995       P995             44            1             6
# 996       P996             37            2             6
# 997       P997             25            2             4
# 998       P998             18            2             6
# 999       P999             47            1             6
#
#      occupational_hazards  genetic_risk  chronic_lung_disease  balanced_diet  \
# 0                       4             5                     4              3
# 1                       1             5                     3              4
# ...
